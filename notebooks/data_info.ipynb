# %%
import pandas as pd
from pathlib import Path

data_path = Path("../data/processed/raw_merged.parquet")
df = pd.read_parquet(data_path)

df.head()
# Out:
#          time_ms  orientation_0  orientation_1  orientation_2  orientation_3  \
# 0  1653819322093       0.998987       0.002905      -0.044690      -0.004504
# 1  1653819322103       0.998996       0.002682      -0.044552      -0.003946
# 2  1653819322113       0.999005       0.002451      -0.044404      -0.003397
# 3  1653819322123       0.999013       0.002225      -0.044261      -0.002843
# 4  1653819322133       0.999021       0.002012      -0.044138      -0.002273
#
#    orientation_4  orientation_5  orientation_6  orientation_7  orientation_8  \
# 0       0.997571       0.002792      -0.069455      -0.004575       0.991368
# 1       0.997583       0.002583      -0.069317      -0.004012       0.991389
# 2       0.997596       0.002366      -0.069169      -0.003457       0.991411
# 3       0.997608       0.002153      -0.069026      -0.002898       0.991432
# 4       0.997619       0.001955      -0.068903      -0.002322       0.991450
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                time_ms  orientation_0  orientation_1  orientation_2  \
# 0        1653819322093       0.998987       0.002905      -0.044690
# 1        1653819322103       0.998996       0.002682      -0.044552
# 2        1653819322113       0.999005       0.002451      -0.044404
# 3        1653819322123       0.999013       0.002225      -0.044261
# 4        1653819322133       0.999021       0.002012      -0.044138
# ...                ...            ...            ...            ...
# 1437351  1672915310675       0.995453      -0.014053       0.038193
# 1437352  1672915310685       0.995439      -0.014052       0.038153
# 1437353  1672915310694       0.995419      -0.014051       0.038153
# 1437354  1672915310704       0.995402      -0.014053       0.038210
# 1437355  1672915310714       0.995384      -0.014056       0.038268
#
#          orientation_3  orientation_4  orientation_5  orientation_6  \
# ...
