# %%
import pandas as pd 
from pathlib import Path

BASE_DIR: Path = Path.cwd().parent
DATA_DIR: Path = BASE_DIR / "data"
PROCESSED_DIR: Path = DATA_DIR / "processed"
SLIM_GAIT_PARQUET: Path = PROCESSED_DIR / "slim_gait.parquet"
df = pd.read_parquet(SLIM_GAIT_PARQUET)

# %%
df
# Out:
#               time_ms group subject_id speed      file_name  footContacts_0  \
# 0       1653819322093  ACLD      ACLD9  fast  fast-001.mvnx             1.0
# 1       1653819322103  ACLD      ACLD9  fast  fast-001.mvnx             1.0
# 2       1653819322113  ACLD      ACLD9  fast  fast-001.mvnx             1.0
# 3       1653819322123  ACLD      ACLD9  fast  fast-001.mvnx             1.0
# 4       1653819322133  ACLD      ACLD9  fast  fast-001.mvnx             1.0
# ...               ...   ...        ...   ...            ...             ...
# 995139  1672915310675    HA       HA10  slow  slow-001.mvnx             1.0
# 995140  1672915310685    HA       HA10  slow  slow-001.mvnx             1.0
# 995141  1672915310694    HA       HA10  slow  slow-001.mvnx             1.0
# 995142  1672915310704    HA       HA10  slow  slow-001.mvnx             1.0
# 995143  1672915310714    HA       HA10  slow  slow-001.mvnx             1.0
#
#         footContacts_1  footContacts_2  footContacts_3  jointAngle_42  ...  \
# 0                  0.0             1.0             0.0       0.015560  ...
# 1                  0.0             1.0             0.0       0.022594  ...
# 2                  0.0             1.0             0.0       0.029944  ...
# 3                  0.0             1.0             0.0       0.037132  ...
# 4                  0.0             1.0             0.0       0.043674  ...
# ...                ...             ...             ...            ...  ...
# 995139             1.0             1.0             0.0      -3.704335  ...
# 995140             1.0             1.0             0.0      -3.714427  ...
# 995141             1.0             1.0             0.0      -3.733907  ...
# 995142             1.0             1.0             0.0      -3.755068  ...
# 995143             1.0             1.0             0.0      -3.776222  ...
#
#         jointAngle_50  jointAngle_54  jointAngle_55  jointAngle_56  \
# 0            6.498350       0.684866     -15.560705      -7.295623
# 1            6.477507       0.743806     -15.512952      -7.277299
# 2            6.455938       0.804467     -15.467804      -7.257289
# 3            6.434731       0.864234     -15.421333      -7.237991
# 4            6.414971       0.920500     -15.369614      -7.221802
# ...               ...            ...            ...            ...
# 995139       8.034441      -0.878850       0.652100      -1.365279
# 995140       7.994314      -0.859159       0.652137      -1.371689
# 995141       7.919479      -0.821713       0.651961      -1.373960
# 995142       7.840517      -0.779815       0.649058      -1.369583
# 995143       7.761531      -0.737919       0.646154      -1.365193
#
#         jointAngle_57  jointAngle_58  jointAngle_59  jointAngle_60  \
# 0           -0.454556      -0.696520       2.468168       0.125871
# 1           -0.537413      -0.711358       2.470414       0.179183
# 2           -0.622446      -0.726357       2.474097       0.232959
# 3           -0.706387      -0.741288       2.477074       0.286480
# 4           -0.785970      -0.755926       2.477193       0.339029
# ...               ...            ...            ...            ...
# 995139      -1.548974       2.206913      -2.551123       6.718480
# 995140      -1.578727       2.227793      -2.551550       6.722203
# 995141      -1.637159       2.260443      -2.548108       6.732562
# 995142      -1.703453       2.294369      -2.541882       6.745860
# 995143      -1.769741       2.328309      -2.535617       6.759158
#
#         jointAngle_61  jointAngle_62
# 0           -8.893226       7.159127
# 1           -8.863551       7.169363
# 2           -8.832089       7.180142
# 3           -8.801482       7.190702
# 4           -8.774374       7.200276
# ...               ...            ...
# 995139       0.328873       2.813937
# 995140       0.331953       2.814222
# 995141       0.330407       2.817860
# 995142       0.324646       2.824367
# 995143       0.318888       2.830872
#
# [995144 rows x 27 columns]
